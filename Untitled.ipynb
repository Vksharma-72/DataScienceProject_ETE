# %%
import pandas as pd
from box import Configbox
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from box import Configbox
#
# ImportError: cannot import name 'Configbox' from 'box' (/home/vk/Desktop/Python Code/Pytorch/Pytorchlib/lib/python3.11/site-packages/box/__init__.py)
